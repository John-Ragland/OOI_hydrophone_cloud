# %% [markdown]
# # Pyramid Exploration

# %%
import xarray as xr
import ODLintake
from xrsignal import xrsignal
from dask.distributed import Client
from OOI_hydrophone_cloud import utils as cloud_utils
import pandas as pd

import holoviews as hv

from holoviews.operation.datashader import datashade
from holoviews.operation import decimate
import holoviews.operation.pyramid as hpyr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [54], in <cell line: 12>()
#      10 from holoviews.operation.datashader import datashade
#      11 from holoviews.operation import decimate
# ---> 12 import holoviews.operation.pyramid as hpyr
#
# ModuleNotFoundError: No module named 'holoviews.operation.pyramid'

# %%
client = Client()
client
# Out:
# 2023-06-14 16:42:07,771 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-0qmadr8l', purging
# 2023-06-14 16:42:07,772 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-dek32wvj', purging
# 2023-06-14 16:42:07,772 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-kb0zimyp', purging
# 2023-06-14 16:42:07,773 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-v900lq7i', purging
# 2023-06-14 16:42:07,773 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-6fhqdjcs', purging
# 2023-06-14 16:42:07,773 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-an7v8n39', purging
# ...

# %%
hdata = ODLintake.open_ooi_lfhydrophones()
hdata_slice = cloud_utils.slice_ds(hdata, pd.Timestamp('2017-01-01'), pd.Timestamp('2017-03-01'), include_coord=False)['AXBA1']

# %%
time_coord = pd.date_range(pd.Timestamp('2017-01-01'), pd.Timestamp('2017-02-28T23:59:59'), freq='1H')
spec = spec.assign_coords({'time':time_coord})

# %%
spec = xrsignal.welch(hdata_slice, dim='time', nperseg=2048, dB=True).compute()

# %%
spec1 = spec.rolling(time=24, min_periods=1).mean()[:,::24]
spec2 = spec.rolling(time=12, min_periods=1).mean()[:,::12]

# %%
tile_1 = hv.Image(spec)
tile_2 = hv.Image(spec1)
tile_3 = hv.Image(spec2)

# %%
pyramid = hpyr.pyramid([tile_1, tile_2, tile_3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
# ----> 1 pyramid = hpyr.pyramid([tile_1, tile_2, tile_3])
#
# NameError: name 'hpyr' is not defined
