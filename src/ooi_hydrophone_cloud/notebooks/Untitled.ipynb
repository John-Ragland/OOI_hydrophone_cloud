# %% [markdown]
# # Calculate pre-processed CSD

# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import signal
import ODLintake
from OOI_hydrophone_cloud import utils
from xrsignal.xrsignal import xrsignal
from NI_tools.NI_tools import calculate
from dask.distributed import Client
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:43065' processes=8 threads=32, memory=62.79 GiB>

# %%
hdata = ODLintake.open_ooi_lfhydrophones()[['AXCC1', 'AXEC2']]

# %%
hdata_pp = calculate.preprocess(hdata, dim='time', include_coords=False)

# %%
csd = xrsignal.csd(hdata_pp, dim='time', db=False, nperseg=1024)

# %%
csd
# Out:
# <xarray.DataArray 'psd across time dimension' (time_frequency: 513, time: 70632)>
# dask.array<<this-array>-__csd_chunk, shape=(513, 70632), dtype=float64, chunksize=(513, 1), chunktype=numpy.ndarray>
# Coordinates:
#   * time_frequency  (time_frequency) float64 0.0 0.0009766 ... 0.499 0.5
# Dimensions without coordinates: time
