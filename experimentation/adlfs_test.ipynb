# %% [markdown]
# # testing out tutorial in adlfs readme

# %%
import xarray as xr

storage_options={'account_name': 'lfhydrophone', 'account_key': 'UohL6H3jDaDLliug0g2Lg5qZZNKWdyxkq2S5KYLE0EFwLjo09auQp48PyhBRKJtYsfjXMmie/d/9+AStLFAniQ=='}

ds = xr.open_zarr('abfs://hydrophonedata/test.zarr', storage_options=storage_options)

# %% [markdown]
# ## Can I write to the blob?
#
# YES!

# %%
import numpy as np
import xarray as xr

x1 = xr.DataArray(np.random.rand(1000), dims=['time'], name='x1')
x2 = xr.DataArray(np.random.rand(1000), dims=['time'], name='x2')

# %%
x = xr.Dataset({'x1':x1, 'x2':x2})
x
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1000)
# Dimensions without coordinates: time
# Data variables:
#     x1       (time) float64 0.06552 0.4606 0.4068 ... 0.4188 0.4787 0.5692
#     x2       (time) float64 0.4696 0.1808 0.1128 0.5945 ... 0.3027 0.2758 0.9072

# %%
storage_options={'account_name': 'lfhydrophone', 'account_key': 'UohL6H3jDaDLliug0g2Lg5qZZNKWdyxkq2S5KYLE0EFwLjo09auQp48PyhBRKJtYsfjXMmie/d/9+AStLFAniQ=='}

result = x.to_zarr('abfs://hydrophonedata/test2.zarr', storage_options=storage_options, append_dim="time")

# %%
storage_options={'account_name': 'lfhydrophone', 'account_key': 'UohL6H3jDaDLliug0g2Lg5qZZNKWdyxkq2S5KYLE0EFwLjo09auQp48PyhBRKJtYsfjXMmie/d/9+AStLFAniQ=='}
ds = xr.open_zarr('abfs://hydrophonedata/test2.zarr', storage_options=storage_options)

# %%
ds.x1.mean().compute()
# Out:
# <xarray.DataArray 'x1' ()>
# array(0.49686193)
